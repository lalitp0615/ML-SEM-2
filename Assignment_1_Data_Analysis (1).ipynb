# %% [markdown]
# NAME : - LALIT PATHADE
#
# ROLL NO :-58
#
# PRN :-12411458
#
# DIV :-CSAI , BATCH 3
#
# KAGGLE DATASET :- https://www.kaggle.com/datasets/yasserh/titanic-dataset?resource=download
#
# ASSIGNMENT - 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#  Data Loading

# %%
df_csv = pd.read_csv("Titanic-Dataset.csv")
df_csv.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
#  check the shape

# %%
df_csv.shape
# Out:
# (891, 12)

# %% [markdown]
# missing values

# %%
df_csv.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Finding Data Type of Each Column

# %%
df_csv.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
(df_csv == 0).sum()
# Out:
# PassengerId      0
# Survived       549
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp          608
# Parch          678
# Ticket           0
# Fare            15
# Cabin            0
# Embarked         0
# dtype: int64

# %% [markdown]
# Finding Zero Values

# %%
(df_csv == 0).sum()
# Out:
# PassengerId      0
# Survived       549
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp          608
# Parch          678
# Ticket           0
# Fare            15
# Cabin            0
# Embarked         0
# dtype: int64

# %% [markdown]
#  Indexing and Selecting Data

# %%
df_csv.iloc[0:5]
df_csv['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
#  Sorting Data

# %%
df_csv.sort_values(by='Fare', ascending=True)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 815          816         0       1                    Fry, Mr. Richard
# 806          807         0       1              Andrews, Mr. Thomas Jr
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 481          482         0       2    Frost, Mr. Anthony Wood "Archie"
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %% [markdown]
# Describing Attributes of Data

# %%
df_csv.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
#  Counting Unique Values

# %%
df_csv.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# Format of Each Column

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
#  Converting Variable Data Type

# %%
df_csv['Age'] = df_csv['Age'].astype(float)

# %% [markdown]
# data frame

# %%
data = {
    'ID': [1, 2, 3, 4, 5],
    'Name': ['Amit', 'Neha', 'Rahul', 'Pooja', 'Karan'],
    'Age': [22, 25, None, 24, 0],
    'Marks': [78.5, 82.0, 90.0, None, 0],
    'City': ['Pune', 'Mumbai', 'Delhi', 'Pune', 'Mumbai']
}

df = pd.DataFrame(data)
df
# Out:
#    ID   Name   Age  Marks    City
# 0   1   Amit  22.0   78.5    Pune
# 1   2   Neha  25.0   82.0  Mumbai
# 2   3  Rahul   NaN   90.0   Delhi
# 3   4  Pooja  24.0    NaN    Pune
# 4   5  Karan   0.0    0.0  Mumbai

# %%
df_csv.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df_csv.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df_csv.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_csv.to_numpy()
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
df_csv.sort_index()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[["Name", "Age"]]
# Out:
#     Name   Age
# 0   Amit  22.0
# 1   Neha  25.0
# 2  Rahul   NaN
# 3  Pooja  24.0
# 4  Karan   0.0

# %%
df.Age
# Out:
# 0    22.0
# 1    25.0
# 2     NaN
# 3    24.0
# 4     0.0
# Name: Age, dtype: float64

# %%
df[0:3]
# Out:
#    ID   Name   Age  Marks    City
# 0   1   Amit  22.0   78.5    Pune
# 1   2   Neha  25.0   82.0  Mumbai
# 2   3  Rahul   NaN   90.0   Delhi

# %%
df.iloc[3:5, 0:2]
# Out:
#    ID   Name
# 3   4  Pooja
# 4   5  Karan

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#    ID   Age
# 1   2  25.0
# 2   3   NaN
# 4   5   0.0

# %%
df.iloc[1:3, :]
# Out:
#    ID   Name   Age  Marks    City
# 1   2   Neha  25.0   82.0  Mumbai
# 2   3  Rahul   NaN   90.0   Delhi

# %%
df.iloc[:, 1:3]
# Out:
#     Name   Age
# 0   Amit  22.0
# 1   Neha  25.0
# 2  Rahul   NaN
# 3  Pooja  24.0
# 4  Karan   0.0

# %%
df.iloc[1, 1]
# Out:
# 'Neha'

# %%
df.iat[1, 1]
# Out:
# 'Neha'

# %%
df_csv.fillna(value = 0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["Age"] > 0]
# Out:
#    ID   Name   Age  Marks    City
# 0   1   Amit  22.0   78.5    Pune
# 1   2   Neha  25.0   82.0  Mumbai
# 3   4  Pooja  24.0    NaN    Pune

# %%
df_csv.iat[0, 1] = 0

# %% [markdown]
# shape

# %%
df.shape
# Out:
# (5, 5)

# %% [markdown]
# MISSING VALUES

# %%
df.isnull().sum()
# Out:
# ID       0
# Name     0
# Age      1
# Marks    1
# City     0
# dtype: int64

# %% [markdown]
# DESCRIBING THE DATA

# %%
df.describe()
# Out:
#              ID        Age      Marks
# count  5.000000   4.000000   4.000000
# mean   3.000000  17.750000  62.625000
# std    1.581139  11.898879  42.026529
# min    1.000000   0.000000   0.000000
# 25%    2.000000  16.500000  58.875000
# 50%    3.000000  23.000000  80.250000
# 75%    4.000000  24.250000  84.000000
# max    5.000000  25.000000  90.000000
